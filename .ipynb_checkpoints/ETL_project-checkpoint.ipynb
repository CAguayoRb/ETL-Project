# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
bitcoin_file = "Resources/coin_Bitcoin.csv"
bitcoin_df = pd.read_csv(bitcoin_file)
bitcoin_df.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
litecoin_file = "Resources/coin_Litecoin.csv"
litecoin_df = pd.read_csv(litecoin_file)
litecoin_df.head()
# Out:
#    SNo      Name Symbol                 Date     High      Low     Open  \
# 0    1  Litecoin    LTC  2013-04-29 23:59:59  4.57360  4.22564  4.36676
# 1    2  Litecoin    LTC  2013-04-30 23:59:59  4.57238  4.16896  4.40352
# 2    3  Litecoin    LTC  2013-05-01 23:59:59  4.35686  3.52029  4.28954
# 3    4  Litecoin    LTC  2013-05-02 23:59:59  4.03930  3.00717  3.78002
# 4    5  Litecoin    LTC  2013-05-03 23:59:59  3.45361  2.39594  3.39044
#
#      Close  Volume     Marketcap
# 0  4.38390     0.0  7.538896e+07
# 1  4.29649     0.0  7.402092e+07
# 2  3.80101     0.0  6.560460e+07
# 3  3.37198     0.0  5.828798e+07
# 4  3.04491     0.0  5.269485e+07

# %%
TSLA_file = "Resources/TSLA.csv"
TSLA_df = pd.read_csv(TSLA_file)
TSLA_df.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
bitcoin_df.Date.str.split(expand=True,)
# Out:
#                0         1
# 0     2013-04-29  23:59:59
# 1     2013-04-30  23:59:59
# 2     2013-05-01  23:59:59
# 3     2013-05-02  23:59:59
# 4     2013-05-03  23:59:59
# ...          ...       ...
# 2857  2021-02-23  23:59:59
# 2858  2021-02-24  23:59:59
# 2859  2021-02-25  23:59:59
# 2860  2021-02-26  23:59:59
# 2861  2021-02-27  23:59:59
#
# [2862 rows x 2 columns]

# %%
bitcoin_df.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
bitcoin_df[['Date','Time']] = bitcoin_df.Name.str.split(" ",expand=True,)
bitcoin_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-69d6c609abc0> in <module>
# ----> 1 bitcoin_df[['Date','Time']] = bitcoin_df.Name.str.split(" ",expand=True,)
#       2 bitcoin_df.head()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3158             self._setitem_frame(key, value)
#    3159         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3160             self._setitem_array(key, value)
#    3161         else:
#    3162             # set column
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    3187             if isinstance(value, DataFrame):
#    3188                 if len(value.columns) != len(key):
# -> 3189                     raise ValueError("Columns must be same length as key")
# ...

# %%
new_bitcoin_df = bitcoin_df[['Name', 'Date','']]
